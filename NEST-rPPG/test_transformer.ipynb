# %%
import sys
print(sys.executable)
# Out:
# /home/psa14/projects/NEST-rPPG/NEST-rPPG/rppg-env/bin/python

# %%
import torch
from model import BaseNet, arc_net, transformer_net

dummy = torch.randn(2, 3, 9, 128)
base  = BaseNet();        base.eval()
arc   = arc_net();        arc.eval()
trans = transformer_net(); trans.eval()

with torch.no_grad():
    s1, h1, a1 = base(dummy)
    s2, h2, a2 = arc(dummy)
    s3, h3, a3 = trans(dummy)

print("BaseNet      — Sig:", s1.shape, "HR:", h1.shape, "av:", a1.shape)
print("arc_net      — Sig:", s2.shape, "HR:", h2.shape, "av:", a2.shape)
print("transformer  — Sig:", s3.shape, "HR:", h3.shape, "av:", a3.shape)

assert s1.shape == s3.shape and h1.shape == h3.shape and a1.shape == a3.shape
print("✓ transformer_net shapes match BaseNet")
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /home/psa14/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 93.7MB/s]
# BaseNet      — Sig: torch.Size([2, 1, 128]) HR: torch.Size([2, 1]) av: torch.Size([2, 960])
# arc_net      — Sig: torch.Size([2, 1, 128]) HR: torch.Size([2, 1]) av: torch.Size([2, 960])
# transformer  — Sig: torch.Size([2, 1, 64]) HR: torch.Size([2, 1]) av: torch.Size([2, 960])
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[2], line 18
#      15 print("arc_net      — Sig:", s2.shape, "HR:", h2.shape, "av:", a2.shape)
#      16 print("transformer  — Sig:", s3.shape, "HR:", h3.shape, "av:", a3.shape)
# ---> 18 assert s1.shape == s3.shape and h1.shape == h3.shape and a1.shape == a3.shape
#      19 print("✓ transformer_net shapes match BaseNet")
#
# AssertionError:
